# %% [markdown]
# ### What's one thing he said that connects to something you've already lived through -- not in a classroom, but in your actual life?
#
# ##### One thing that relates to my life is when he said that a core part is Quantum Mechanics is not focusing on what is right, but rather the curiosity that drives the discovery of new things. This not only applies to computers, but also real life. When everything we do revolves around finding the right answer, we might miss the true meaning od what we're doing. So, instead, I learnt to stop prefecting everything, when I can spend time discovering new things.

# %% [markdown]
# ### Think of a decision you made where you couldn't know the outcome until you commited to it. How is that like measurement collapsing during a qubit?
#
# ##### A descion I made was when I was thinking about whether I should go to regular Stamford High of choose the IB Program. I've heard that IB is a lot more intense with more projects and homework compared to a few other highschools. Going there means I anm risking not getting as good grade as I used to, but now I realise it is much better to push myself. A higher rish results in a higher reward.

# %% [markdown]
# ### Question 3 Answer:
#
# ##### My friends and I often have jokes and topics that we talk about thats no one else understands. Someone outside might think we sound crazy but we talk about things in a way that only we would understand -- like inside jokes.
